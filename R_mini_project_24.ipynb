# %% [markdown]
# <a href="https://colab.research.google.com/github/sayali0204/R-LAB1/blob/main/R_mini_project_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
id <- "1-H4PQQLpDZlxvowud4GlnrgIiLny0lVs" # google file ID
data <- read.csv(sprintf("https://docs.google.com/uc?id=%s&export=download", id), na.strings=c("","NA"))

# %%
data
# Out:
#      id    gender age   hypertension heart_disease ever_married work_type
# 1     9046 Male   67    0            1             Yes          Private
# 2    51676 Female 61    0            0             Yes          Self-employed
# 3    31112 Male   80    0            1             Yes          Private
# 4    60182 Female 49    0            0             Yes          Private
# 5     1665 Female 79    1            0             Yes          Self-employed
# 6    56669 Male   81    0            0             Yes          Private
# 7    53882 Male   74    1            1             Yes          Private
# 8    10434 Female 69    0            0             No           Private
# 9    27419 Female 59    0            0             Yes          Private
# 10   60491 Female 78    0            0             Yes          Private
# 11   12109 Female 81    1            0             Yes          Private
# 12   12095 Female 61    0            1             Yes          Govt_job
# ...

# %%
# a. summarize the entire data using apropriate R Command.
library(dplyr)

summary(data)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#        id           gender               age         hypertension
#  Min.   :   67   Length:5110        Min.   : 0.08   Min.   :0.00000
#  1st Qu.:17741   Class :character   1st Qu.:25.00   1st Qu.:0.00000
#  Median :36932   Mode  :character   Median :45.00   Median :0.00000
#  Mean   :36518                      Mean   :43.23   Mean   :0.09746
#  3rd Qu.:54682                      3rd Qu.:61.00   3rd Qu.:0.00000
#  Max.   :72940                      Max.   :82.00   Max.   :1.00000
#  heart_disease     ever_married        work_type         Residence_type
#  Min.   :0.00000   Length:5110        Length:5110        Length:5110
#  1st Qu.:0.00000   Class :character   Class :character   Class :character
#  Median :0.00000   Mode  :character   Mode  :character   Mode  :character
# ...

# %%
# b. show class of variable holding data
class(data)
# Out:
# [1] "data.frame"

# %%
# c. Obtain 5 point statistical summary for all attri
summary(data)
# Out:
#        id           gender               age         hypertension
#  Min.   :   67   Length:5110        Min.   : 0.08   Min.   :0.00000
#  1st Qu.:17741   Class :character   1st Qu.:25.00   1st Qu.:0.00000
#  Median :36932   Mode  :character   Median :45.00   Median :0.00000
#  Mean   :36518                      Mean   :43.23   Mean   :0.09746
#  3rd Qu.:54682                      3rd Qu.:61.00   3rd Qu.:0.00000
#  Max.   :72940                      Max.   :82.00   Max.   :1.00000
#  heart_disease     ever_married        work_type         Residence_type
#  Min.   :0.00000   Length:5110        Length:5110        Length:5110
#  1st Qu.:0.00000   Class :character   Class :character   Class :character
#  Median :0.00000   Mode  :character   Mode  :character   Mode  :character
#  Mean   :0.05401
#  3rd Qu.:0.00000
#  Max.   :1.00000
#  avg_glucose_level     bmi            smoking_status         stroke
#  Min.   : 55.12    Length:5110        Length:5110        Min.   :0.00000
# ...

# %%
# d. select any 2 atributes that are continuous valued and create a subset of original data with only those columns. 
# (e.g. sample_data(col1,col2, col3) is stored in variable my_data where as variable data_slice has only col2 and col3 and no other columns. Num of rows in both must be same.)


data_slice <- data %>% select(age:heart_disease)
summary(data_slice)
# Out:
#       age         hypertension     heart_disease
#  Min.   : 0.08   Min.   :0.00000   Min.   :0.00000
#  1st Qu.:25.00   1st Qu.:0.00000   1st Qu.:0.00000
#  Median :45.00   Median :0.00000   Median :0.00000
#  Mean   :43.23   Mean   :0.09746   Mean   :0.05401
#  3rd Qu.:61.00   3rd Qu.:0.00000   3rd Qu.:0.00000
#  Max.   :82.00   Max.   :1.00000   Max.   :1.00000

# %%
# e. Write R function to sample tuples starting at index N to N+m from any data set provided.
bb <- data['age']
sample(bb[1:10,])
# Out:
#  [1] 79 69 80 61 74 59 81 67 49 78

# %%
# b. select colum with more than 10% values missing for deletation. Create new copy of dataset
# that has one less column call it sample_data_1less.

## Remove columns with more than 10% NA
dataless1 <-data[, which(colMeans(!is.na(data)) > 0.1)]

# %%
# c. Find 5 point summary of all remaining columns with numric attributes
summary(dataless1)
# Out:
#        id           gender               age         hypertension
#  Min.   :   67   Length:5110        Min.   : 0.08   Min.   :0.00000
#  1st Qu.:17741   Class :character   1st Qu.:25.00   1st Qu.:0.00000
#  Median :36932   Mode  :character   Median :45.00   Median :0.00000
#  Mean   :36518                      Mean   :43.23   Mean   :0.09746
#  3rd Qu.:54682                      3rd Qu.:61.00   3rd Qu.:0.00000
#  Max.   :72940                      Max.   :82.00   Max.   :1.00000
#  heart_disease     ever_married        work_type         Residence_type
#  Min.   :0.00000   Length:5110        Length:5110        Length:5110
#  1st Qu.:0.00000   Class :character   Class :character   Class :character
#  Median :0.00000   Mode  :character   Mode  :character   Mode  :character
#  Mean   :0.05401
#  3rd Qu.:0.00000
#  Max.   :1.00000
#  avg_glucose_level     bmi            smoking_status         stroke
#  Min.   : 55.12    Length:5110        Length:5110        Min.   :0.00000
# ...

# %%
# d. For attribute having maximum spread delete all tuples that have value less than the mean of the
# attribute selected. Count the number of tuples reamining in the sampled dataset.

m <- mean(data$age, na.rm = FALSE)
m

df2 <- subset(data, data$age< m)
summary(df2$age)
print('Rows before row deletion: ')
nrow(data)
print('Rows before row deletion: ')
nrow(df2)
# Out:
# [1] 43.22661
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.08   13.00   24.00   23.36   34.00   43.00
# [1] "Rows before row deletion: "
# [1] 5110
# [1] "Rows before row deletion: "
# [1] 2458

# %%
# a. print the 5 point statistical summary for any 2 numeric attributes from your data set
fivenum(data$age) 
fivenum(data$avg_glucose_level)
# Out:
# [1]  0.08 25.00 45.00 61.00 82.00
# [1]  55.120  77.240  91.885 114.090 271.740

# %%
# b. select 2 atributes have closest mean value and draw a scatter plot with proper x and labelsloi
# ntt and title (for plotting you must use R library functions or gnuplot and not matplotlib )
means<- colMeans(data[sapply(data, is.numeric)] )
means

library(ggplot2)

age<-data$age
avg_glucose_level<-data$avg_glucose_level
plot(data$age , data$avg_glucose_level , main = "Scatterplot" , xlab = "age" , ylab = "avg_glucose_level" , las = 1 , xlim = c(0,100) , col = 4 )
# Out:
#                id               age      hypertension     heart_disease
#      3.651783e+04      4.322661e+01      9.745597e-02      5.401174e-02
# avg_glucose_level            stroke
#      1.061477e+02      4.872798e-02
# Plot with title “Scatterplot”

# %%
# e. Write a R function to plot histogram of some specific input attribute for any data set provided
new.function <- function(age) {
   hist(age)
}

new.function(age)
# Out:
# Plot with title “Histogram of age”

# %%
# c. Find coefficient of correlation using some R library function between above 2 attributes
cor(age,avg_glucose_level, method = c("pearson", "kendall", "spearman"))
# Out:
# [1] 0.2381711

# %%
boxplot(age,avg_glucose_level)
title("age vs. avg_glucose_level")
# Out:
# Plot with title “age vs. avg_glucose_level”
